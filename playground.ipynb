# %%
import asyncio
from crawl4ai import *

async def main():
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun(
            url="https://corfo.cl/sites/cpp/regiones/coquimbo/",
        )
        return result.markdown.split('\n######')


resp = await main()
# Out:
# [INIT].... → Crawl4AI 0.7.4
# [FETCH]... ↓ https://corfo.cl/sites/cpp/regiones/coquimbo/                                                        |
# ✓ | ⏱: 2.47s
# [SCRAPE].. ◆ https://corfo.cl/sites/cpp/regiones/coquimbo/                                                        |
# ✓ | ⏱: 0.02s
# [COMPLETE] ● https://corfo.cl/sites/cpp/regiones/coquimbo/                                                        |
# ✓ | ⏱: 2.50s

# %%
resp
# Out:
# ['![Site in english](https://corfo.cl/sites/cpp/wp-content/uploads/2025/01/icono-england.png) [ Sitio en inglés ](https://corfo.cl/sites/cpp/web-ingles/)\n![Contáctanos](https://corfo.cl/sites/cpp/wp-content/uploads/2025/01/icono-dialogo.png) [ Contáctanos ](https://corfo.cl/sites/cpp/contacto/)\n  * [ ![Instagram Corfo](https://corfo.cl/sites/cpp/wp-content/uploads/2025/01/icono-instagram.png) ](https://www.instagram.com/corfochile)\n  * [ ![Facebook de Corfo](https://corfo.cl/sites/cpp/wp-content/uploads/2025/01/icono-facebook.png) ](http://www.facebook.com/CorfoChile)\n  * [ ![Youtube](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/icono-youtube-1.png) ](http://www.youtube.com/corfotv)\n  * [ ![](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/icono-twitter-1.png) ](http://www.twitter.com/corfo)\n  * [ ![](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/icono-linkedin-1.png) ](https://www.linkedin.com/company/corfo/)\n  * [ ![](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/icono-spotify-1.png) ](https://open.spotify.com/show/2SHUKeLfWoReey2gb1ScZn?si=9T3omFnaT--H7PS6TR_hJQ)\n\n\n![Ingresar usuarios](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/icono-puerta.png) [ Ingreso usuario ](https://login.corfo.cl/gsi/login/Login.aspx?uid=WEB297&env=produccion-cloud&enforcelogin=1)\n[ ![Corfo](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/logo_corfo2024_azul_min.png) ](https://corfo.cl/sites/cpp)\n  * [Inicio](https://corfo.cl/sites/cpp/ "Inicio")\n  * [Sobre Corfo](https://corfo.cl/sites/cpp/sobrecorfo/ "Sobre Corfo")\n  * [Programas y Convocatorias](https://corfo.cl/sites/cpp/programasyconvocatorias/ "Programas y Convocatorias")\n  * [Sala de Prensa](https://corfo.cl/sites/cpp/sala-de-prensa/ "Sala de Prensa")\n  * [Regiones](https://corfo.cl/sites/cpp/regiones/coquimbo/ "Regiones")\n    * [Arica y Parinacota](https://corfo.cl/sites/cpp/regiones/aricaparinacota/ "Arica y Parinacota")\n    * [Tarapacá](https://corfo.cl/sites/cpp/regiones/tarapaca/ "Tarapacá")\n    * [Antofagasta](https://corfo.cl/sites/cpp/regiones/antofagasta/ "Antofagasta")\n    * [Atacama](https://corfo.cl/sites/cpp/regiones/atacama/ "Atacama")\n    * [Coquimbo](https://corfo.cl/sites/cpp/regiones/coquimbo/ "Coquimbo")\n    * [Valparaíso](https://corfo.cl/sites/cpp/regiones/valparaiso/ "Valparaíso")\n    * [Metropolitana](https://corfo.cl/sites/cpp/regiones/metropolitana/ "Metropolitana")\n    * [O´Higgins](https://corfo.cl/sites/cpp/regiones/ohiggins/ "O´Higgins")\n    * [Maule](https://corfo.cl/sites/cpp/regiones/maule/ "Maule")\n    * [Ñuble](https://corfo.cl/sites/cpp/regiones/nuble/ "Ñuble")\n    * [Biobío](https://corfo.cl/sites/cpp/regiones/biobio/ "Biobío")\n    * [Araucanía](https://corfo.cl/sites/cpp/regiones/araucania/ "Araucanía")\n    * [Los Ríos](https://corfo.cl/sites/cpp/regiones/los-rios/ "Los Ríos")\n    * [Los Lagos](https://corfo.cl/sites/cpp/regiones/los-lagos/ "Los Lagos")\n    * [Aysén](https://corfo.cl/sites/cpp/regiones/aysen/ "Aysén")\n    * [Magallanes y Antártica Chilena](https://corfo.cl/sites/cpp/regiones/magallanes/ "Magallanes y Antártica Chilena")\n\n\n  * [Inicio](https://corfo.cl/sites/cpp/regiones/coquimbo/#section-contenido_destacado-0)\n  * [Programas](https://corfo.cl/sites/cpp/regiones/coquimbo/#section-programas_relacionados-3)\n  * [Noticias](https://corfo.cl/sites/cpp/regiones/coquimbo/#section-noticias-4)\n  * [Contacto](https://corfo.cl/sites/cpp/regiones/coquimbo/#section-contactanos-5)\n\n\n![CORFO](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02/coquimbo.png)\n#### Corfo Coquimbo\nLa Región de Coquimbo se caracteriza por tener una economía diversificada, destacándose en el PIB los sectores asociados a la minería, la agricultura, la pesca, el turismo y la construcción.',
#  ' SECTORES PRODUCTIVOS\nComo Corfo, trabajamos por el crecimiento y la reactivación de nuestros territorios a través de estrategias para fomentar la competitividad del turismo y astroturismo, los bioproductos marinos, el sector caprino y pisquero, la tecnología, las industrias creativas, la pesca, la acuicultura y la minería, para así ser un referente en materia de sostenibilidad y desarrollo regional.',
#  ' EJES DE TRABAJO\nCon una fuerte apuesta por la economía sustentable y la innovación, dentro de las áreas de trabajo de la Dirección Regional de Corfo destaca el triple impacto a través de programas emblemáticos que buscan por medio de la agregación de valor, impulsar el desarrollo de una oferta de productos diferenciadores e innovadores dirigidos hacia mercados locales, así como aquéllos de exigente demanda.\nCon un desarrollado ecosistema de emprendimiento, se acentúa el trabajo realizado junto al Gobierno Regional por reactivar y dinamizar al sector, generando un mayor empleo, creación nuevas empresas y democratizando las oportunidades para emprender.\n![Andrés Zurita Silva - CORFO](https://corfo.cl/sites/cpp/wp-content/uploads/2025/02
2025\n[Más Información](https://corfo.cl/sites/cpp/convocatoria/red-asociativa-agro-desarrollo-silvoagropecuario-sustentable-diagnostico-2025/)\nINVIERTE Redes de Ángeles \nAlcance: Todo Chile \nSe busca apoyar en la organización, fortalecimiento y operación de las Redes, a través de la preparación y fidelización de inversionistas y emprendedores, logrando mayor transferencia de capacidades entre ellos, fomentar la inversión privada y mejorar sus condiciones de éxito y crecimiento.',
#  ' Apertura\n30/07/2025',
#  ' Cierre\n08/09/2025\n[Más Información](https://corfo.cl/sites/cpp/convocatoria/invierte-redes-angeles-2025/)\nINVIERTE Plataformas de Crowdfunding \nAlcance: Todo Chile \nSe busca apoyar la organización, fortalecimiento y operación de las plataformas de financiamiento colectivo de equity a través de la diversificación de la inversión y el aumento de alternativas de acceso a capitales para emprendimientos con potencial de crecimiento y desarrollar negocios innovadores. Además de entregar acceso y alternatiavs para invertir en emprendimientos con potencial de ser dinámicos.',
#  ' Apertura\n30/07/2025',
#  ' Cierre\n08/09/2025\n[Más Información](https://corfo.cl/sites/cpp/convocatoria/invierte-plataformas-crowdfunding-2025/)\nSelección Ejecutor 2° Etapa Transforma Territorio Circular \nAlcance: Todo Chile \nLlamado a concurso para la selección de ejecutor para la administración de la segunda etapa implementación del proyecto transforma nacional denominado “Territorio Circular”, código 21PEDN-184106-4, en el marco del instrumento “Transforma”.',
#  ' Apertura\n17/07/2025',
#  ' Cierre\n31/07/2025\n[Más Información](https://corfo.cl/sites/cpp/convocatoria/seleccion-ejecutor-2-etapa-transforma-territorio-circular-2025/)\nSelección Ejecutor 1° Etapa Implementación Transforma Innovación en Salud \nAlcance: Todo Chile \nLlamado a concurso para la selección de ejecutor para la administración de la primera etapa implementación del proyecto transforma nacional denominado “transforma innovacion en salud”, código 23pedn-246816-2, en el marco del instrumento “transforma”.',
#  ' Apertura\n17/07/2025',
#  ' Cierre\n31/07/2025\n[Más Información](https://corfo.cl/sites/cpp/convocatoria/seleccion-ejecutor-primera-etapa-implementacion-transforma-innovacion-salud-2025/)\n  * 1\n  * [2](https://corfo.cl/sites/cpp/regiones/coquimbo/?paged=2)\n  * ...\n  * [34](https://corfo.cl/sites/cpp/regiones/coquimbo/?paged=34)\n  * [Siguiente](https://corfo.cl/sites/cpp/regiones/coquimbo/?paged=2)\n\n\n* * *\nNoticias de la Región de Coquimbo \n![](https://saowcsblobassets.blob.core.windows.net/assets/WebCorfo/prod-uploads/2025/08/ovalle.jpeg)\n13/08/2025 \n[ Ovalle: emprendedores sobre los 40 años se certifican en innovador programa formativo y potencian sus negocios ](https://corfo.cl/sites/cpp/regional/ovalle-emprendedores-sobre-los-40-anos-se-certifican-en-innovador-programa-formativo-y-potencian-sus-negocios/)\n![](https://saowcsblobassets.blob.core.windows.net/assets/WebCorfo/prod-uploads/2025/08/foto-coquimbo-2.jpg)\n06/08/2025 \n
# %%
import asyncio
import pandas as pd
from playwright.async_api import async_playwright

URL = "https://corfo.cl/sites/cpp/regiones/coquimbo/"

async def scrape_page(page):
    """Extrae todas las tarjetas visibles en la página actual"""
    await page.wait_for_timeout(2500)  # dejar que cargue JS

    # Espera a que aparezcan las tarjetas
    try:
        await page.wait_for_selector("div", timeout=10000)
    except:
        print("⚠️ No se encontraron tarjetas en esta página")
        return []

    cards = await page.query_selector_all("div")
    data = []
    print(cards)
    for card in cards:
        print(card)
        title_el = await card.query_selector("h3 a")
        title = (await title_el.inner_text()).strip() if title_el else ""
        link = (await title_el.get_attribute("href")) if title_el else ""

        estado_el = await card.query_selector("span.estado")
        estado = (await estado_el.inner_text()).strip() if estado_el else ""

        fechas_el = await card.query_selector_all("div.fechas p")
        apertura = fechas_el[0].inner_text() if len(fechas_el) >= 1 else ""
        cierre = fechas_el[1].inner_text() if len(fechas_el) >= 2 else ""

        territorio_el = await card.query_selector("div.territorio p")
        territorio = (await territorio_el.inner_text()).strip() if territorio_el else ""

        resumen_el = await card.query_selector("p")
        resumen = (await resumen_el.inner_text()).strip() if resumen_el else ""

        if title and link:
            data.append({
                "titulo": title,
                "enlace": link,
                "estado": estado,
                "apertura": apertura,
                "cierre": cierre,
                "territorio": territorio,
                "resumen": resumen
            })
    return data

async def main():
    all_data = []
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False, slow_mo=300)  # ver navegador
        page = await browser.new_page()

        await page.goto(URL)
        page_num = 1

        while True:
            print(f"\n🌐 Scrapeando página {page_num}")
            rows = await scrape_page(page)
            print(page)
            if not rows:
                break
            all_data.extend(rows)

            # Intentar click en "Siguiente"
            try:
                next_btn = await page.query_selector("a.ui-paginator-next")
                if not next_btn:
                    break
                disabled = await next_btn.get_attribute("aria-disabled")
                if disabled == "true":
                    break
                await next_btn.click()
                await page.wait_for_timeout(2000)  # dejar cargar nuevas tarjetas
                page_num += 1
            except:
                break

        await browser.close()

    # Guardar CSV
    df = pd.DataFrame(all_data).drop_duplicates(subset=["titulo", "enlace"]).reset_index(drop=True)
    df.to_csv("corfo_convocatorias.csv", index=False, encoding="utf-8-sig")
    print(df)
    print(f"\n✅ Guardado en corfo_convocatorias.csv ({len(df)} filas)")








await main()
# Out:
# 🌐 Scrapeando página 1
# ⚠️ No se encontraron tarjetas en esta página
# <Page url='https://corfo.cl/sites/cpp/regiones/coquimbo/'>
# Empty DataFrame
# Columns: []
# Index: []
#
# ✅ Guardado en corfo_convocatorias.csv (0 filas)
